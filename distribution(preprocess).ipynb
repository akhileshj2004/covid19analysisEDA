# %% [markdown]
# # Covid-19 Statewise Vaccine Analysis
#
# ### Details of the Team
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
dataframe = pd.read_csv(r"D:\Study\SEM 4\EDA project\covid_reducedrows.csv")
dataframe
# Out:
#       Updated on                         State  Total Doses Administered  \
# 0           44212  Andaman and Nicobar Islands                      23.0
# 1           44213  Andaman and Nicobar Islands                      23.0
# 2           44214  Andaman and Nicobar Islands                      42.0
# 3           44215  Andaman and Nicobar Islands                      89.0
# 4           44216  Andaman and Nicobar Islands                     124.0
# ...           ...                          ...                       ...
# 7623        44414                  West Bengal                31774086.0
# 7624        44415                  West Bengal                32029325.0
# 7625        44416                  West Bengal                32098768.0
# 7626        44417                  West Bengal                32390378.0
# 7627        44418                  West Bengal                       NaN
#
#       Sessions   Sites   First Dose Administered  Second Dose Administered  \
# ...

# %%
dataframe.isnull().sum()
# Out:
# Updated on                                0
# State                                     0
# Total Doses Administered                213
# Sessions                                213
#  Sites                                  213
# First Dose Administered                 213
# Second Dose Administered                213
# Male (Doses Administered)               213
# Female (Doses Administered)             213
# Transgender (Doses Administered)        213
#  Covaxin (Doses Administered)           213
# CoviShield (Doses Administered)         213
# Sputnik V (Doses Administered)         4714
# AEFI                                   2337
# 18-44 Years (Doses Administered)       5972
# 45-60 Years (Doses Administered)       5972
# 60+ Years (Doses Administered)         5972
# 18-44 Years(Individuals Vaccinated)    3996
# 45-60 Years(Individuals Vaccinated)    3995
# 60+ Years(Individuals Vaccinated)      3995
# Male(Individuals Vaccinated)           7628
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7628 entries, 0 to 7627
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Updated on                           7628 non-null   int64
#  1   State                                7628 non-null   object
#  2   Total Doses Administered             7415 non-null   float64
#  3   Sessions                             7415 non-null   float64
#  4    Sites                               7415 non-null   float64
#  5   First Dose Administered              7415 non-null   float64
#  6   Second Dose Administered             7415 non-null   float64
#  7   Male (Doses Administered)            7415 non-null   float64
#  8   Female (Doses Administered)          7415 non-null   float64
#  9   Transgender (Doses Administered)     7415 non-null   float64
#  10   Covaxin (Doses Administered)        7415 non-null   float64
# ...

# %% [markdown]
# # DISTRIBUTION ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder 
from mpl_toolkits.mplot3d import Axes3D

# %%
sns.kdeplot(dataframe['Updated on '],shade=True)
plt.title('KDE Plot for Updated on')
plt.xlabel('Updated on')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\448339694.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Updated on '],shade=True)

# %%
sns.kdeplot(dataframe['Total Doses Administered'],shade=True)
plt.title('KDE Plot for Total Doses Administered')
plt.xlabel('Total Doses Administered')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\2211785103.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Total Doses Administered'],shade=True)

# %%
sns.kdeplot(dataframe['Sessions'],shade=True)
plt.title('KDE Plot for Sessions')
plt.xlabel('Sessions')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\2045076663.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Sessions'],shade=True)

# %%
sns.kdeplot(dataframe[' Sites '],shade=True)
plt.title('KDE Plot for Sites')
plt.xlabel('Sites')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\1322056357.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe[' Sites '],shade=True)

# %%
sns.kdeplot(dataframe['First Dose Administered'],shade=True)
plt.title('KDE Plot for First Dose Administered')
plt.xlabel('First Dose Administered')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\2693114972.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['First Dose Administered'],shade=True)

# %%
sns.kdeplot(dataframe['Second Dose Administered'],shade=True)
plt.title('KDE Plot for Second Dose Administered')
plt.xlabel('Second Dose Administered')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3985054963.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Second Dose Administered'],shade=True)

# %%
sns.kdeplot(dataframe['Male (Doses Administered)'],shade=True)
plt.title('KDE Plot for Male (Doses Administered)')
plt.xlabel('Male(Dose Administered)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3836299754.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Male (Doses Administered)'],shade=True)

# %%
sns.kdeplot(dataframe['Female (Doses Administered)'],shade=True)
plt.title('KDE Plot for Female (Doses Administered)')
plt.xlabel('Female (Dose Administered)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\1243301520.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Female (Doses Administered)'],shade=True)

# %%
sns.kdeplot(dataframe['Transgender (Doses Administered)'],shade=True)
plt.title('KDE Plot for Transgender (Doses Administered)')
plt.xlabel('Transegender (Dose Administered)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\4284520867.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Transgender (Doses Administered)'],shade=True)

# %%
sns.kdeplot(dataframe[' Covaxin (Doses Administered)'],shade=True)
plt.title('KDE Plot for Covaxin (Doses Administered)')
plt.xlabel('Covaxin (Dose Administered)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\633013007.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe[' Covaxin (Doses Administered)'],shade=True)

# %%
sns.kdeplot(dataframe['CoviShield (Doses Administered)'],shade=True)
plt.title('KDE Plot for CoviShield (Doses Administered)')
plt.xlabel('CoviShield (Dose Administered)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3731880838.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['CoviShield (Doses Administered)'],shade=True)

# %%
sns.kdeplot(dataframe['Sputnik V (Doses Administered)'],shade=True)
plt.title('KDE Plot for Sputnik V (Doses Administered)')
plt.xlabel('Sputnik V (Dose Administered)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\1102445354.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Sputnik V (Doses Administered)'],shade=True)

# %%
sns.kdeplot(dataframe['AEFI'],shade=True)
plt.title('KDE Plot for AEFI')
plt.xlabel('AEFI')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\1265665318.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['AEFI'],shade=True)

# %%
sns.kdeplot(dataframe['18-44 Years (Doses Administered)'],shade=True)
plt.title('KDE Plot for 18-44 Years (Doses Administered)')
plt.xlabel('18-44 Years (Doses Administered)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3224502926.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['18-44 Years (Doses Administered)'],shade=True)

# %%
sns.kdeplot(dataframe['45-60 Years (Doses Administered)'],shade=True)
plt.title('KDE Plot for 45-60 Years (Doses Administered)')
plt.xlabel('45-60 Years (Doses Administered)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3879973147.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['45-60 Years (Doses Administered)'],shade=True)

# %%
sns.kdeplot(dataframe['60+ Years (Doses Administered)'],shade=True)
plt.title('KDE Plot for 60+ Years (Doses Administered)')
plt.xlabel('60+ Years (Doses Administered)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3278310870.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['60+ Years (Doses Administered)'],shade=True)

# %%
sns.kdeplot(dataframe['18-44 Years(Individuals Vaccinated)'],shade=True)
plt.title('KDE Plot for 18-44 Years(Individuals Vaccinated)')
plt.xlabel('18-44 Years(Individuals Vaccinated)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3911089447.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['18-44 Years(Individuals Vaccinated)'],shade=True)

# %%
sns.kdeplot(dataframe['45-60 Years(Individuals Vaccinated)'],shade=True)
plt.title('KDE Plot for 45-60 Years(Individuals Vaccinated)')
plt.xlabel('45-60 Years(Individuals Vaccinated)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\2653957915.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['45-60 Years(Individuals Vaccinated)'],shade=True)

# %%
sns.kdeplot(dataframe['60+ Years(Individuals Vaccinated)'],shade=True)
plt.title('KDE Plot for 60+ Years(Individuals Vaccinated)')
plt.xlabel('60+ Years(Individuals Vaccinated)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\1773453706.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['60+ Years(Individuals Vaccinated)'],shade=True)

# %%
sns.kdeplot(dataframe['Male(Individuals Vaccinated)'],shade=True)
plt.title('KDE Plot for Male(Individuals Vaccinated)')
plt.xlabel('Male(Individuals Vaccinated)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3167291340.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Male(Individuals Vaccinated)'],shade=True)
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3167291340.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataframe['Male(Individuals Vaccinated)'],shade=True)

# %%
sns.kdeplot(dataframe['Female(Individuals Vaccinated)'],shade=True)
plt.title('KDE Plot for Female(Individuals Vaccinated)')
plt.xlabel('Female(Individuals Vaccinated)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3556152461.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Female(Individuals Vaccinated)'],shade=True)
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3556152461.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataframe['Female(Individuals Vaccinated)'],shade=True)

# %%
sns.kdeplot(dataframe['Transgender(Individuals Vaccinated)'],shade=True)
plt.title('KDE Plot for Transgender(Individuals Vaccinated)')
plt.xlabel('Transgender(Individuals Vaccinated)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3923336084.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Transgender(Individuals Vaccinated)'],shade=True)
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\3923336084.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataframe['Transgender(Individuals Vaccinated)'],shade=True)

# %%
sns.kdeplot(dataframe['Total Individuals Vaccinated'],shade=True)
plt.title('KDE Plot for Total Individuals Vaccinated')
plt.xlabel('Total Individuals Vaccinated')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\seeba\AppData\Local\Temp\ipykernel_5844\2432100757.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe['Total Individuals Vaccinated'],shade=True)
